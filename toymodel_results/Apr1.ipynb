# %% [markdown]
# ## Dustmap
#
# For both color excess and extinction, Dustmap have exteremely high values compared when the actual Gaia value around 0. The ranges of extinction and color excess value from Dustamp are larger, especially when the corresponding value in Gaia is close 0. (For all the NaN entries I filled in with 0)
#
# <table>
#  <tr>
#     <td> <img src="Ag.png" alt="Drawing" style="width: 400px;"/> </td>
#     <td> <img src="ebp_rp.png" alt="Drawing" style="width: 400px;"/> </td>
#  </tr>
#  </table>
#
#  Zoom in to the very dense low $E(BP\_RP)$ region:
#  <table>
#  <tr>
#         <td> <img src="./Apr1/Ag_zoomed.png" alt="Drawing" style="width: 400px;"/> </td>
#     <td> <img src="./Apr1/ebp_rp_zoomed.png" alt="Drawing" style="width: 400px;"/> </td>
#  </tr>
#  </table>

# %% [markdown]
# 2D histoggram comparision:
# Again, the ranges of $A_G$ and $E(BP-RP)$ are larger for result calculated from Dustmap. We see a extremely high density at (0,0) because I made all NaN entries to 0.
# <table>
#  <tr>
#     <td> <img src="./Apr1/2dhist_Dustmap.png" alt="Drawing" style="width: 400px;"/> </td>
#     <td> <img src="./Apr1/2dhist_Gaia.png" alt="Drawing" style="width: 400px;"/> </td>
#  </tr>
#  </table>
#  Although we see a straight line with slope 1/3, but it is super hard to see any feature because of the hight density at (0,0).
#  <img src="./Apr1/scatter_Dustmap.png/">

# %% [markdown]
# ## 3D simulation
#
# smoother orbit integration:
# ![orbit_integration.png](attachment:orbit_integration.png)
# vr$\neq$ 0
# distribution of vr:
# <img src="./quasiisothermal/quasi_4pc_b20mulcosb.png" alt="Drawing" style="width: 250px;"/>
#
# #### Varying d range
# $d<4kpc, |b|<20$ V.S. $d<2kpc, |b|<20$ V.S. $d<1kpc, |b|<20$ (# of test particles: 25560->7818->989
# <table>
#  <tr>
#     <td> <img src="./quasiisothermal/quasi_4pc_b20mulcosb.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/quasi_2pc_b20mulcosb.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/quasi_1pc_b20mulcosb.png" alt="Drawing" style="width: 250px;"/> </td>
#  </tr>
#  <tr>
#     <td> <img src="./quasiisothermal/quasi_4pc_b20vlosD.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/quasi_2pc_b20vlosD.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/quasi_1pc_b20vlosD.png" alt="Drawing" style="width: 250px;"/> </td>
#  </tr>
#  </table>
#
# #### Varying b range at 2kpc and fitting $\mu_l$ and $v_{los}$ with one likelihood function
# $d<2kpc, |b|<10$ vs $d<2kpc, |b|<20$ vs $d<2kpc, |b|<30$ vs $d<1kpc, |b|<40$
# <table>
#  <tr>
#     <td> <img src="./quasiisothermal/quasi_2pc_b10mulcosb.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/quasi_2pc_b20mulcosb.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/quasi_2pc_b30mulcosb.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/quasi_2pc_b40mulcosb.png" alt="Drawing" style="width: 250px;"/> </td>
#  </tr>
#
#   <tr>
#     <td> <img src="./quasiisothermal/2pcb10mul_fit.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/2pcb20mul_fit.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/2pcb30mul_fit.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/2pcb40mul_fit.png" alt="Drawing" style="width: 250px;"/> </td>
#  </tr>
#
#  <tr>
#     <td> <img src="./quasiisothermal/quasi_2pc_b10vlosD.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/quasi_2pc_b20vlosD.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/quasi_2pc_b30vlosD.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/quasi_2pc_b40vlosD.png" alt="Drawing" style="width: 250px;"/> </td>
#
#  </tr>
#
#    <tr>
#     <td> <img src="./quasiisothermal/2pcb10vlos_fit.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/2pcb20vlos_fit.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/2pcb30vlos_fit.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/2pcb40vlos_fit.png" alt="Drawing" style="width: 250px;"/> </td>
#  </tr>
#
#  </table>
#
#
# | group|  $|b|<10$ | $|b|<20$  |  $|b|<30$  |  $|b|<40$  |
# | --- | --- | --- | --- | ---|
# |A,B,C,K|14.62, -12.47, 1.28, 0.048|14.72, -12.48, 1.32, 0.17|14.62, -12.48, 1.29, -0.0013|14.49, -12.49, 1.28, -0.054|
# |just $\mu_l$ A,B,C| 14.69, -12.47, 1.24 |14.69, -12.48, 1.28|14.69, -12.48, 1.4|14.71, -12.49, 1.24|
# |Residual standard deviation ($\mu_l$, $v_{los}$, $\mu_b$)|2.37,1.83,7.80|2.29,1.84,7.76|2.25,1.87.7.69|2.19,1.87.7.61|
#
# How well do these parameters fit $\mu_b$?:
# <table>
#    <tr>
#     <td> <img src="./quasiisothermal/2pcb10b3050mub_fit.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/2pcb3050mub_fit.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/2pcb30b3050mub_fit.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="./quasiisothermal/2pcb40b3050mub_fit.png" alt="Drawing" style="width: 250px;"/> </td>
#  </tr>
# </table>
# MLE fitting $\mu_b$ alone: A,C,K = 4.76,0.73,-0.12
# <td> <img src="./quasiisothermal/2pcb3050mub_fit_self.png",style ="width: 300px;"/> </td>
#
# $\sqrt{\frac{\sum (y-y_{pred})^2}{n-4}}$

# %% [markdown]
# ## DR2 data
# For each color population, I used the u0,v0,w0 estimated from $\mu_l$ and $v_{los}$ to correct $mu_b$:
# $\Delta_{\mu_b} =\frac{1}{\sin b \cos b} (\mu_b-\varpi[(u_0cosl+v_0sinl)sinb-w_0cosb])$
# It seems $\Delta_{\mu_b}$ do not provide good data to fit Oort constants.
# ![mub08_deltamub.png](attachment:mub08_deltamub.png)![mub12_deltamub.png](attachment:mub12_deltamub.png)
#
# You commented that perhaps these stars are no on circular orbits. I looked at their phaseplot
#    $R_{\odot} =8.34kpc$, $z_{\odot} = 27pc$, $v_{\phi\odot}=220 km/s$
#   <table>
#     <tr>
#         <td> <img src=".\Apr1\b4050vrVSvphi.png"/> </td>
#         <td> <img src=".\Apr1\b20vrVSvphi.png"/> </td>
#     </tr>
#   </table>
#   Yes, for the |b|~40-50, the distribution of $v_r$ is more spreadout from 0 than the stars with |b|<20.
#
# About determining the uncertainties in our 4 parameters (four Oort constants):
# randomly perturb the data points within the error of each data point, the perturbation term should follow the Guassian dist with mean value of 0 and sigma as the error of the corresponding data point.
#
# Then I can estimate the best-fit parameters based on the new data points. Repeat this process for 100 times, you can get 100 different samples and best-fit parameters. The std of these parameters are their corresponding error
# - This is MCMC, right? I think I have codes ready for MCMC, but the error for data point is what I am confused with.
# - error of the corresponding data point: error in $\Delta \mu_l$, $\Delta v_{los}$ and $\Delta \mu_b$
#    these need error propogataion (partial derivative rules, super long terms)
# - Li and Bovy said their error came from error propogataion via coordiante transformation.
