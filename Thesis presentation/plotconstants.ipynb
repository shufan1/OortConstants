# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rc('font', family='sans-serif')
plt.rc('text', usetex=True)

color = np.array([0.6,1.0,1.4,1.8,2.2,2.6])
A= np.array([15.00,15.93,16.78,15.83,17.15,17.02])
B= np.array([-13.32,-13.18,-13.35,-13.36,-12.88,-12.64])
C= np.array([-1.66,-1.96,-2.32,-2.70,-2.00,-0.94])
K=np.array([-0.93,-0.67,-2.18,-2.09,-3.20,0])
A_error = np.array([0.24,0.31,0.40,0.44,0.83,2.12])
B_error = np.array([0.22,0.24,0.28,0.38,0.55,1.43])
C_error = np.array([0.31,0.26,0.33,0.46,0.78,2.16])
K_error = np.array([0.36,0.43,1.04,1.09,1.49,0])


plt.errorbar(color, A,yerr = A_error,fmt='k.',markersize=10)
plt.errorbar(1.2, 15.52,yerr = 0.22 ,fmt='b.',markersize=20,label='$<1.2$')
plt.legend()
plt.ylabel('A(km/s/kpc)',fontsize=20)
plt.xlabel('$BP-RP-E(BP\_RP)$',fontsize=20)
ax=plt.gca()
ax.axhspan(14.9,15.7, facecolor='grey', alpha=0.3)
ax.annotate('Bovy, 2017',xy=(0.76,0.18),xycoords='axes fraction',fontsize=18)
ax.axhspan(15,15.2, facecolor='blue', alpha=0.1)
ax.annotate('Li, 2019',xy=(0.78,0.09),xycoords='axes fraction',fontsize=18)
plt.savefig('A.png')
plt.show()

# %%
plt.errorbar(color, B,yerr = B_error,fmt='k.',markersize=10)
plt.errorbar(1.2, -13.33,yerr = 0.17 ,fmt='b.',markersize=20,label='$<1.2$')
plt.ylabel('B(km/s/kpc)',fontsize=20)
plt.xlabel('$BP-RP-E(BP\_RP)$',fontsize=20)
plt.legend()
ax=plt.gca()
ax.axhspan(-12.3,-11.5, facecolor='grey', alpha=0.3)
ax.annotate('Bovy, 2017',xy=(0.76,0.67),xycoords='axes fraction',fontsize=18)
ax.axhspan(-13.5,-13.3, facecolor='blue', alpha=0.1)
ax.annotate('Li, 2019',xy=(0.78,0.21),xycoords='axes fraction',fontsize=18)

plt.savefig('B.png')
plt.show()

plt.errorbar(color, C,yerr = C_error,fmt='k.',markersize=10)
plt.errorbar(1.2, -1.88,yerr = 0.08 ,fmt='b.',markersize=15,label='$<1.2$')
plt.ylabel('C(km/s/kpc)',fontsize=20)
plt.xlabel('$BP-RP-E(BP\_RP)$',fontsize=20)
plt.errorbar(color, C,yerr = C_error,fmt='k.',markersize=10)
plt.ylabel('C(km/s/kpc)',fontsize=20)
plt.xlabel('$BP-RP-E(BP\_RP)$',fontsize=20)
plt.legend()
ax=plt.gca()
ax.axhspan(-3.6,-2.8, facecolor='grey', alpha=0.3)
ax.annotate('Bovy, 2017',xy=(0.76,0.1),xycoords='axes fraction',fontsize=18)
ax.axhspan(-2.8,-2.6, facecolor='blue', alpha=0.1)
ax.annotate('Li, 2019',xy=(0.78,0.2),xycoords='axes fraction',fontsize=18)
plt.savefig('C.png')

plt.show()

plt.errorbar(color[:-1], K[:-1],yerr = K_error[:-1],fmt='k.',markersize=10)
plt.errorbar(1.2, -1.86,yerr = 0.19 ,fmt='b.',markersize=15,label='$<1.2$')
plt.ylabel('K(km/s/kpc)',fontsize=20)
plt.xlabel('$BP-RP-E(BP\_RP)$',fontsize=20)
plt.ylim(-5,0.1)
plt.xlim(0.50,2.7)
plt.legend()
ax=plt.gca()
ax.axhspan(-3.9,-2.7, facecolor='grey', alpha=0.3)
ax.annotate('Bovy, 2017',xy=(0.78,0.25),xycoords='axes fraction',fontsize=16)
ax.axhspan(-1.9,-1.5, facecolor='blue', alpha=0.1)
ax.annotate('Li, 2019',xy=(0.81,0.60),xycoords='axes fraction',fontsize=16)
# plt.show()
plt.savefig('K.png')
plt.show()
